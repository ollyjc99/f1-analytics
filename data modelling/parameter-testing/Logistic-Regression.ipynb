# %%
import pandas as pd
import numpy as np
import warnings

from sklearn.metrics import confusion_matrix, precision_score
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.preprocessing import StandardScaler

from sys import platform

if platform == "win32":
    path = 'C:/Users/olive/GitHub/f1-analytics/'
elif platform == "darwin":
    path = '~/Documents/GitHub/f1-analytics/'

warnings.filterwarnings("ignore", category=RuntimeWarning) 
pd.options.mode.chained_assignment = None  # default='warn'

# %matplotlib inline

# %%
ml_data = pd.read_csv(path+'data/ml_input.csv')
data = pd.read_csv(path+'data/merged.csv')

# %%
### Season to test results

N = 2022

# %%
comparison_dict = {
    'model':[],
    'gamma': [],
    'C': [],
    'kernel': [],
    'score': []
    }

# %%
def format_points(x):
    scoring = {
    1: 25.,
    2: 18.,
    3: 15.,
    4: 12.,
    5: 10.,
    6: 8.,
    7: 6.,
    8: 4.,
    9: 2.,
    10: 1.
}

    if x in scoring:
        return scoring[x]
    else:
        return 0

# %%
df = ml_data.copy()
df['points'] = df.podium.map(lambda x: format_points(x))

train = df[df.season < N]

scaler = StandardScaler()
X_train = train.drop(['podium', 'points'], axis=1)

print(X_train.shape)
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)

y_train = np.asarray(train.points.values)
# Out:
# (2680, 48)

# %%
def score_classification(model):
    correct_predictions = 0
    
    for circuit in df[df.season == N]['round'].unique():

        test = df[(df.season == N) & (df['round'] == circuit)]
        X_test = test.drop(['podium', 'points'], axis=1)
        y_test = test.points

        # Scaling
        X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)


        # Make Predictions
        prediction_df = pd.DataFrame(model.predict_proba(X_test), columns=['prob_25','prob_18','prob_15','prob_12','prob_10','prob_8','prob_6','prob_4','prob_2','prob_1','prob_0'])

        # prediction_df['actual'] = y_test.reset_index(drop=True)
        # prediction_df.sort_values('proba_1', ascending=False, inplace=True)
        # prediction_df.reset_index(inplace = True, drop=True)
        # prediction_df['predicted'] = prediction_df.index

        # correct_predictions += precision_score(prediction_df.actual, prediction_df.predicted)

    return prediction_df
    # return correct_predictions / df[df.season == N]['round'].nunique()

# %%
# Logistic Regression

params={'penalty': ['l1', 'l2'],
        'solver': ['saga', 'liblinear'],
        'C': np.logspace(-3,1,20)}

for penalty in params['penalty']:
    for solver in params['solver']:
        for c in params['C']:
            model_params = (penalty, solver, c)
            model = LogisticRegression(penalty=penalty, solver=solver, C=c, max_iter=10000)
            model.fit(X_train, y_train)
            
            model_score = score_classification(model)
            break
        break
    break
            
            # comparison_dict['model'].append('logistic_regression')
            # comparison_dict['params'].append(model_params)
            # comparison_dict['score'].append(model_score)

# %%
model_score
# Out:
#     prob_25   prob_18   prob_15   prob_12   prob_10    prob_8    prob_6  \
# 0   0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 1   0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 2   0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 3   0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 4   0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 5   0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 6   0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 7   0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 8   0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 9   0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 10  0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 11  0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 12  0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 13  0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 14  0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 15  0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 16  0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
# 17  0.48765  0.051484  0.051496  0.051121  0.051126  0.051869  0.051121
#
#       prob_4    prob_2    prob_1  prob_0
# 0   0.050378  0.051123  0.051131  0.0515
# 1   0.050378  0.051123  0.051131  0.0515
# 2   0.050378  0.051123  0.051131  0.0515
# 3   0.050378  0.051123  0.051131  0.0515
# 4   0.050378  0.051123  0.051131  0.0515
# 5   0.050378  0.051123  0.051131  0.0515
# 6   0.050378  0.051123  0.051131  0.0515
# 7   0.050378  0.051123  0.051131  0.0515
# 8   0.050378  0.051123  0.051131  0.0515
# 9   0.050378  0.051123  0.051131  0.0515
# 10  0.050378  0.051123  0.051131  0.0515
# 11  0.050378  0.051123  0.051131  0.0515
# 12  0.050378  0.051123  0.051131  0.0515
# 13  0.050378  0.051123  0.051131  0.0515
# 14  0.050378  0.051123  0.051131  0.0515
# 15  0.050378  0.051123  0.051131  0.0515
# 16  0.050378  0.051123  0.051131  0.0515
# 17  0.050378  0.051123  0.051131  0.0515

# %%
comparison_df = pd.DataFrame(comparison_dict)

comparison_df.sort_values('score', ascending=False)
