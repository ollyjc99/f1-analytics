# %%
# %pylab inline
import pandas as pd
from sys import platform
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from geopy.geocoders import Nominatim
import folium

if platform == "win32":
    path = 'C:/Users/olive/GitHub/f1-analytics/'
elif platform == "darwin":
    path = '~/Documents/GitHub/f1-analytics/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
### Load race and mereged DataFrames

data = pd.read_csv(path + 'data/races.csv')
merged = pd.read_csv(path + 'data/merged.csv')

# %%
data
# Out:
#     season  round     circuit_id       country      lat      long        date  \
# 0     2020      1  red_bull_ring       Austria  47.2197  14.76470  2020-07-05
# 1     2020      2  red_bull_ring       Austria  47.2197  14.76470  2020-07-12
# 2     2020      3    hungaroring       Hungary  47.5789  19.24860  2020-07-19
# 3     2020      4    silverstone            UK  52.0786  -1.01694  2020-08-02
# 4     2020      5    silverstone            UK  52.0786  -1.01694  2020-08-09
# 5     2020      6      catalunya         Spain  41.5700   2.26111  2020-08-16
# 6     2020      7            spa       Belgium  50.4372   5.97139  2020-08-30
# 7     2020      8          monza         Italy  45.6156   9.28111  2020-09-06
# 8     2020      9        mugello         Italy  43.9975  11.37190  2020-09-13
# 9     2020     10          sochi        Russia  43.4057  39.95780  2020-09-27
# 10    2020     11    nurburgring       Germany  50.3356   6.94750  2020-10-11
# 11    2020     12       portimao      Portugal  37.2270  -8.62670  2020-10-25
# 12    2020     13          imola         Italy  44.3439  11.71670  2020-11-01
# 13    2020     14       istanbul        Turkey  40.9517  29.40500  2020-11-15
# 14    2020     15        bahrain       Bahrain  26.0325  50.51060  2020-11-29
# 15    2020     16        bahrain       Bahrain  26.0325  50.51060  2020-12-06
# 16    2020     17     yas_marina           UAE  24.4672  54.60310  2020-12-13
# 17    2021      1        bahrain       Bahrain  26.0325  50.51060  2021-03-28
# 18    2021      2          imola         Italy  44.3439  11.71670  2021-04-18
# 19    2021      3       portimao      Portugal  37.2270  -8.62670  2021-05-02
# 20    2021      4      catalunya         Spain  41.5700   2.26111  2021-05-09
# 21    2021      5         monaco        Monaco  43.7347   7.42056  2021-05-23
# 22    2021      6           baku    Azerbaijan  40.3725  49.85330  2021-06-06
# 23    2021      7         ricard        France  43.2506   5.79167  2021-06-20
# 24    2021      8  red_bull_ring       Austria  47.2197  14.76470  2021-06-27
# 25    2021      9  red_bull_ring       Austria  47.2197  14.76470  2021-07-04
# 26    2021     10    silverstone            UK  52.0786  -1.01694  2021-07-18
# 27    2021     11    hungaroring       Hungary  47.5789  19.24860  2021-08-01
# 28    2021     12            spa       Belgium  50.4372   5.97139  2021-08-29
# 29    2021     13      zandvoort   Netherlands  52.3888   4.54092  2021-09-05
# 30    2021     14          monza         Italy  45.6156   9.28111  2021-09-12
# 31    2021     15          sochi        Russia  43.4057  39.95780  2021-09-26
# 32    2021     16       istanbul        Turkey  40.9517  29.40500  2021-10-10
# 36  http://en.wikipedia.org/wiki/2021_Qatar_Grand_...
# 37  http://en.wikipedia.org/wiki/2021_Saudi_Arabia...
# 38  http://en.wikipedia.org/wiki/2021_Abu_Dhabi_Gr...

# %%
geolocator = Nominatim(user_agent="f1_data_analytics_c1835576")

# %%
data_count = data[['country', 'round']].groupby(['country']).count().reset_index()
data_count
# Out:
#          country  round
# 0        Austria      4
# 1     Azerbaijan      1
# 2        Bahrain      3
# 3        Belgium      2
# 4         Brazil      1
# 5         France      1
# 6        Germany      1
# 7        Hungary      2
# 8          Italy      5
# 9         Mexico      1
# 10        Monaco      1
# 11   Netherlands      1
# 12      Portugal      2
# 13         Qatar      1
# 14        Russia      2
# 15  Saudi Arabia      1
# 16         Spain      2
# 17        Turkey      2
# 18           UAE      2
# 19            UK      3
# 20           USA      1

# %%
coords = list(zip(data['lat'], data['long']))

coords[:3]
# Out:
# [(47.2197, 14.7647), (47.2197, 14.7647), (47.5789, 19.2486)]

# %%
folium.Choropleth(
    geo_data=path+'data/world-map.json',
    data=data_count,
    columns=['country', 'round']
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-85-fa08601c44a4> in <module>
# ----> 1 folium.Choropleth(
#       2     geo_data=path+'data/world-map.json',
#       3     data=data_count,
#       4     columns=['country', 'round']
#       5 )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1288                 smooth_factor=smooth_factor)
#    1289         else:
# -> 1290             self.geojson = GeoJson(
#    1291                 geo_data,
#    1292                 style_function=style_function,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/folium/features.py in __init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker)
#     495         self.marker = marker
#     496
# --> 497         self.data = self.process_data(data)
#     498
#     499         if self.style or self.highlight:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/folium/features.py in process_data(self, data)
#     532                 if not self.embed:
#     533                     self.embed_link = data
# --> 534                 with open(data) as f:
#     535                     return json.loads(f.read())
#     536         elif hasattr(data, '__geo_interface__'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/Documents/GitHub/f1-analytics/data/world-map.json'

# %%
map = folium.Map(
    tiles="stamen terrain",
    zoom_control=False,
    scrollWheelZoom=False,
    dragging=False
    )


for x,y  in zip(coords, data['circuit_id']):
    marker = folium.Marker(location=x, popup=y)
    marker.add_to(map)

sw = data[['lat', 'long']].min().values.tolist()
ne = data[['lat', 'long']].max().values.tolist()

map.fit_bounds([sw, ne])
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e584f67f423e5a8fc1dca756bccb1b78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e584f67f423e5a8fc1dca756bccb1b78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e584f67f423e5a8fc1dca756bccb1b78 = L.map(
#                 &quot;map_e584f67f423e5a8fc1dca756bccb1b78&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: false,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bffcfc468bfd8853a7abbf8917c196b8 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e584f67f423e5a8fc1dca756bccb1b78);
#
#
#             var marker_248bc0eac88e817f1d7287bc929788a8 = L.marker(
#                 [47.2197, 14.7647],
#                 {}
#             ).addTo(map_e584f67f423e5a8fc1dca756bccb1b78);
#
#
#         var popup_f03fc71df0b9a5876586258cf1248dea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_617fb56ed17ae8b39cbbb87dc75d3826 = $(`&lt;div id=&quot;html_617fb56ed17ae8b39cbbb87dc75d3826&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;red_bull_ring&lt;/div&gt;`)[0];
#                 popup_f03fc71df0b9a5876586258cf1248dea.setContent(html_617fb56ed17ae8b39cbbb87dc75d3826);
#
#
#
#         marker_248bc0eac88e817f1d7287bc929788a8.bindPopup(popup_f03fc71df0b9a5876586258cf1248dea)
#         ;
#
#
#
#
#             var marker_1cb418cd725914616bc052dd2da051d7 = L.marker(
#                 [47.2197, 14.7647],
#                 {}
#             ).addTo(map_e584f67f423e5a8fc1dca756bccb1b78);
#
#
#         var popup_3df767c60f6d79e708b868e5ba650aaf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_012b185306488f899073d8cd4f559650 = $(`&lt;div id=&quot;html_012b185306488f899073d8cd4f559650&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;red_bull_ring&lt;/div&gt;`)[0];
#                 popup_3df767c60f6d79e708b868e5ba650aaf.setContent(html_012b185306488f899073d8cd4f559650);
#
#
#
#         marker_1cb418cd725914616bc052dd2da051d7.bindPopup(popup_3df767c60f6d79e708b868e5ba650aaf)
#         ;
#
#
#
#
#             var marker_8268cfc7da947ec1bb8cba1d7f303166 = L.marker(
#                 [47.5789, 19.2486],
#                 {}
#             ).addTo(map_e584f67f423e5a8fc1dca756bccb1b78);
#
#
#         var popup_cbbdd13e426781d997305643eb51c866 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e37e91c176217d944a6e775a0f060bd6 = $(`&lt;div id=&quot;html_e37e91c176217d944a6e775a0f060bd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hungaroring&lt;/div&gt;`)[0];
#                 popup_cbbdd13e426781d997305643eb51c866.setContent(html_e37e91c176217d944a6e775a0f060bd6);
#
#
#
#         marker_8268cfc7da947ec1bb8cba1d7f303166.bindPopup(popup_cbbdd13e426781d997305643eb51c866)
#         ;
#
#
#
#
#             var marker_ca37f4d0fdec07773b768f49e786ca1a = L.marker(
#                 [52.0786, -1.01694],
#                 {}
#             ).addTo(map_e584f67f423e5a8fc1dca756bccb1b78);
#
#
#         var popup_079093743828392cc9247ec141929a41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7bcb21f0d3ccc93f9ea9a98473191268 = $(`&lt;div id=&quot;html_7bcb21f0d3ccc93f9ea9a98473191268&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;silverstone&lt;/div&gt;`)[0];
#                 popup_079093743828392cc9247ec141929a41.setContent(html_7bcb21f0d3ccc93f9ea9a98473191268);
#
#
#
#         marker_ca37f4d0fdec07773b768f49e786ca1a.bindPopup(popup_079093743828392cc9247ec141929a41)
#         ;
#
#
#
#
#             var marker_7df2ae82e20b6f4fa7f3eac958df2a54 = L.marker(
#                 [52.0786, -1.01694],
#                 {}
#             ).addTo(map_e584f67f423e5a8fc1dca756bccb1b78);
#
#
#         var popup_c04f8729aaf322ac17f32dcd2ae5fc85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80dc1ebb15e725c1e611aced4754999e = $(`&lt;div id=&quot;html_80dc1ebb15e725c1e611aced4754999e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;silverstone&lt;/div&gt;`)[0];
#                 popup_c04f8729aaf322ac17f32dcd2ae5fc85.setContent(html_80dc1ebb15e725c1e611aced4754999e);
#
#
#
#         marker_7df2ae82e20b6f4fa7f3eac958df2a54.bindPopup(popup_c04f8729aaf322ac17f32dcd2ae5fc85)
#         ;
