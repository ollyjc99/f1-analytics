# %%
# %pylab inline
import pandas as pd
from sys import platform
import matplotlib.pyplot as plt
import numpy as np
from geopy.geocoders import Nominatim

if platform == "win32":
    path = 'C:/Users/olive/GitHub/f1-analytics/'
elif platform == "darwin":
    path = '~/Documents/GitHub/f1-analytics/'
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
### Load race and mereged DataFrames

data = pd.read_csv(path + 'data/processed.csv')

# %%
data.columns
# Out:
# Index(['season', 'round', 'circuit_id', 'driver', 'constructor', 'podium',
#        'driver_points_after_race', 'driver_points', 'driver_wins',
#        'driver_standings_pos', 'constructor_points_after_race',
#        'constructor_points', 'constructor_wins', 'constructor_standings_pos',
#        'qualifying_pos', 'qual_time', 'stage', 'q_delta', 'starting_grid',
#        'driver_points_per_race', 'driver_points_from_race',
#        'constructor_points_per_race', 'constructor_points_from_race',
#        'driver_points_last_3_races', 'driver_points_before_race'],
#       dtype='object')

# %%
data = data[['season', 'round', 'circuit_id', 'driver', 'constructor', 'podium',
       'driver_points_after_race', 'driver_points', 'driver_wins',
       'driver_standings_pos', 'constructor_points_after_race',
       'constructor_points', 'constructor_wins', 'constructor_standings_pos',
       'qualifying_pos', 'qual_time', 'stage', 'q_delta', 'starting_grid',
       'driver_points_per_race', 'driver_points_from_race',
       'constructor_points_per_race', 'constructor_points_from_race',
       'driver_points_last_3_races', 'driver_points_before_race']]

# %%
data.head()
# Out:
#    season  round   circuit_id           driver constructor  podium  \
# 0    2014      1  albert_park     nico_rosberg    mercedes       1
# 1    2014      1  albert_park  kevin_magnussen     mclaren       2
# 2    2014      1  albert_park    jenson_button     mclaren       3
# 3    2014      1  albert_park  fernando_alonso     ferrari       4
# 4    2014      1  albert_park  valtteri_bottas    williams       5
#
#    driver_points_after_race  driver_points  driver_wins  driver_standings_pos  \
# 0                      25.0              0            0                     0
# 1                      18.0              0            0                     0
# 2                      15.0              0            0                     0
# 3                      12.0              0            0                     0
# 4                      10.0              0            0                     0
#
#    ...  qual_time  stage  q_delta  starting_grid  driver_points_per_race  \
# ...

# %%
grouped_podiums = data.groupby('podium').agg({
    'driver_points_last_3_races': 'mean',
    'starting_grid': 'mean',
    'qualifying_pos': 'mean',
    'driver_points_per_race': 'mean',
    'constructor_points_per_race': 'mean'
})
grouped_podiums
# Out:
#         driver_points_last_3_races  starting_grid  qualifying_pos  \
# podium
# 1                        45.005495       2.197802        2.109890
# 2                        37.169444       2.950000        3.050000
# 3                        29.638889       4.527778        4.322222
# 4                        23.653631       5.776536        5.290503
# 5                        22.409341       7.263736        6.862637
# 6                        14.802198       7.796703        7.780220
# 7                        11.840782       8.636872        8.905028
# 8                        10.837079      10.320225       10.320225
# 9                         8.472222      10.638889       10.761111
# 10                        7.258427      11.820225       11.724719
# 11                        5.028249      12.615819       12.768362
# 12                        5.321839      13.816092       13.632184
# 13                        4.870056      13.508475       13.700565
# ...

# %%
merged[['season','round','driver_points_before_race', 'driver_points', 'driver_points_after_race']].query('season == 2021 & round == 12')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 merged[['season','round','driver_points_before_race', 'driver_points', 'driver_points_after_race']].query('season == 2021 & round == 12')
#
# NameError: name 'merged' is not defined
