# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from datetime import datetime

races = pd.read_csv('races.csv')
qualifying = pd.read_csv('qualifying.csv')
constructors = pd.read_csv('constructor_standings.csv')
drivers = pd.read_csv('driver_standings.csv')
results = pd.read_csv('results.csv')
weather = pd.read_csv('weather.csv')

# %%
qualifying.rename(columns={'grid_pos': 'grid'}, inplace=True)

# %%
races
# Out:
#     season  round     circuit_id       country      lat      long        date  \
# 0     2020      1  red_bull_ring       Austria  47.2197  14.76470  2020-07-05
# 1     2020      2  red_bull_ring       Austria  47.2197  14.76470  2020-07-12
# 2     2020      3    hungaroring       Hungary  47.5789  19.24860  2020-07-19
# 3     2020      4    silverstone            UK  52.0786  -1.01694  2020-08-02
# 4     2020      5    silverstone            UK  52.0786  -1.01694  2020-08-09
# 5     2020      6      catalunya         Spain  41.5700   2.26111  2020-08-16
# 6     2020      7            spa       Belgium  50.4372   5.97139  2020-08-30
# 7     2020      8          monza         Italy  45.6156   9.28111  2020-09-06
# 8     2020      9        mugello         Italy  43.9975  11.37190  2020-09-13
# 9     2020     10          sochi        Russia  43.4057  39.95780  2020-09-27
# 10    2020     11    nurburgring       Germany  50.3356   6.94750  2020-10-11
# 11    2020     12       portimao      Portugal  37.2270  -8.62670  2020-10-25
# 12    2020     13          imola         Italy  44.3439  11.71670  2020-11-01
# 13    2020     14       istanbul        Turkey  40.9517  29.40500  2020-11-15
# 14    2020     15        bahrain       Bahrain  26.0325  50.51060  2020-11-29
# 15    2020     16        bahrain       Bahrain  26.0325  50.51060  2020-12-06
# 16    2020     17     yas_marina           UAE  24.4672  54.60310  2020-12-13
# 17    2021      1        bahrain       Bahrain  26.0325  50.51060  2021-03-28
# 18    2021      2          imola         Italy  44.3439  11.71670  2021-04-18
# 19    2021      3       portimao      Portugal  37.2270  -8.62670  2021-05-02
# 20    2021      4      catalunya         Spain  41.5700   2.26111  2021-05-09
# 21    2021      5         monaco        Monaco  43.7347   7.42056  2021-05-23
# 22    2021      6           baku    Azerbaijan  40.3725  49.85330  2021-06-06
# 23    2021      7         ricard        France  43.2506   5.79167  2021-06-20
# 24    2021      8  red_bull_ring       Austria  47.2197  14.76470  2021-06-27
# 25    2021      9  red_bull_ring       Austria  47.2197  14.76470  2021-07-04
# 26    2021     10    silverstone            UK  52.0786  -1.01694  2021-07-18
# 27    2021     11    hungaroring       Hungary  47.5789  19.24860  2021-08-01
# 28    2021     12            spa       Belgium  50.4372   5.97139  2021-08-29
# 29    2021     13      zandvoort   Netherlands  52.3888   4.54092  2021-09-05
# 30    2021     14          monza         Italy  45.6156   9.28111  2021-09-12
# 31    2021     15          sochi        Russia  43.4057  39.95780  2021-09-26
# 32    2021     16       istanbul        Turkey  40.9517  29.40500  2021-10-10
# 33    2021     17       americas           USA  30.1328 -97.64110  2021-10-24
# 34    2021     18      rodriguez        Mexico  19.4042 -99.09070  2021-11-07
# 35    2021     19     interlagos        Brazil -23.7036 -46.69970  2021-11-14
# 36    2021     20         losail         Qatar  25.4900  51.45420  2021-11-21
# 37    2021     21         jeddah  Saudi Arabia  21.6319  39.10440  2021-12-05
# 38    2021     22     yas_marina           UAE  24.4672  54.60310  2021-12-12
#
#                                                   url
# 0   http://en.wikipedia.org/wiki/2020_Austrian_Gra...
# 1   http://en.wikipedia.org/wiki/2020_Styrian_Gran...
# 2   http://en.wikipedia.org/wiki/2020_Hungarian_Gr...
# 3   http://en.wikipedia.org/wiki/2020_British_Gran...
# 4   http://en.wikipedia.org/wiki/70th_Anniversary_...
# 5   http://en.wikipedia.org/wiki/2020_Spanish_Gran...
# 6   http://en.wikipedia.org/wiki/2020_Belgian_Gran...
# 7   http://en.wikipedia.org/wiki/2020_Italian_Gran...
# 8   http://en.wikipedia.org/wiki/2020_Tuscan_Grand...
# 9   http://en.wikipedia.org/wiki/2020_Russian_Gran...
# 10  http://en.wikipedia.org/wiki/2020_Eifel_Grand_...
# 11  http://en.wikipedia.org/wiki/2020_Portuguese_G...
# 12  http://en.wikipedia.org/wiki/2020_Emilia_Romag...
# 13  http://en.wikipedia.org/wiki/2020_Turkish_Gran...
# 14  http://en.wikipedia.org/wiki/2020_Bahrain_Gran...
# 15  http://en.wikipedia.org/wiki/2020_Sakhir_Grand...
# 16  http://en.wikipedia.org/wiki/2020_Abu_Dhabi_Gr...
# 17  http://en.wikipedia.org/wiki/2021_Bahrain_Gran...
# 18  http://en.wikipedia.org/wiki/2021_Emilia_Romag...
# 19  http://en.wikipedia.org/wiki/2021_Portuguese_G...
# 20  http://en.wikipedia.org/wiki/2021_Spanish_Gran...
# 21  http://en.wikipedia.org/wiki/2021_Monaco_Grand...
# 22  http://en.wikipedia.org/wiki/2021_Azerbaijan_G...
# 23  http://en.wikipedia.org/wiki/2021_French_Grand...
# 24  http://en.wikipedia.org/wiki/2021_Styrian_Gran...
# 25  http://en.wikipedia.org/wiki/2021_Austrian_Gra...
# 26  http://en.wikipedia.org/wiki/2021_British_Gran...
# 27  http://en.wikipedia.org/wiki/2021_Hungarian_Gr...
# 28  http://en.wikipedia.org/wiki/2021_Belgian_Gran...
# 29  http://en.wikipedia.org/wiki/2021_Dutch_Grand_...
# 30  http://en.wikipedia.org/wiki/2021_Italian_Gran...
# 31  http://en.wikipedia.org/wiki/2021_Russian_Gran...
# 32  http://en.wikipedia.org/wiki/2021_Turkish_Gran...
# 33  http://en.wikipedia.org/wiki/2021_United_State...
# 34  http://en.wikipedia.org/wiki/2021_Mexican_Gran...
# 35  http://en.wikipedia.org/wiki/2021_S%C3%A3o_Pau...
# 36  http://en.wikipedia.org/wiki/2021_Qatar_Grand_...
# 37  http://en.wikipedia.org/wiki/2021_Saudi_Arabia...
# 38  http://en.wikipedia.org/wiki/2021_Abu_Dhabi_Gr...

# %%
df1 = pd.merge(races, weather, how='inner', on=['season', 'round', 'circuit_id']).drop(['lat', 'long','country','weather'], axis = 1)
df2 = pd.merge(df1, results, how='inner', on=['season', 'round', 'circuit_id']).drop(['url','points', 'status', 'time'], axis = 1)
df3 = pd.merge(df2, drivers, how='left', on=['season', 'round', 'driver']) 
df4 = pd.merge(df3, constructors, how='left', on=['season', 'round', 'constructor'])

final_df = pd.merge(df4, qualifying, how='inner', on=['season', 'round', 'grid']).drop(['driver_x'], axis=1)

# %%
from dateutil.relativedelta import *

final_df['date'] = pd.to_datetime(final_df.date)
final_df['date_of_birth'] = pd.to_datetime(final_df.date_of_birth)
final_df['driver_age'] = final_df.apply(lambda x: relativedelta(x['date'], x['date_of_birth']).years, axis=1)
final_df.drop(['date', 'date_of_birth'], axis = 1, inplace = True)

# %%
# fill/drop nulls

for col in ['driver_points', 'driver_wins', 'driver_standings_pos', 'constructor_points', 
            'constructor_wins' , 'constructor_standings_pos']:
    final_df[col].fillna(0, inplace = True)
    final_df[col] = final_df[col].map(lambda x: int(x))
    
final_df.dropna(inplace = True )

# %%
x = final_df['qualy_time'][0]
x = '1:02.921'
float(str(x).split(':')[1])
print(x[:8])
# Out:
# 1:02.921

# %%
def format_qualifying(x):
    if str(x) == '00.000':
        return 0
    elif len(str(x)) <= 6:
        return float(x)
    elif type(x) == float:
        return "{:.2f}".format(x)
    else:
        print(x)
        return (float(str(x).split(':')[1]) + (60 * float(str(x).split(':')[0])) if x != 0 else 0)

# %%
# calculate difference in qualifying times

final_df['qualy_time'] = final_df.qualy_time.map(lambda x: format_qualifying(x))

final_df = final_df[final_df['qualy_time'] != 0]
final_df.sort_values(['season', 'round', 'grid'], inplace = True)
final_df['qualifying_time_diff'] = final_df.groupby(['season', 'round']).qualy_time.diff()
final_df['qualifying_time'] = final_df.groupby(['season', 'round']).qualy_time_diff.cumsum().fillna(0)
final_df.drop('qualifying_time_diff', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expressions.py:71, in _evaluate_standard(op, op_str, a, b)
#      70     _store_test_result(False)
# ---> 71 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [66], line 7
#       5 final_df = final_df[final_df['qualy_time'] != 0]
#       6 final_df.sort_values(['season', 'round', 'grid'], inplace = True)
# ----> 7 final_df['qualifying_time_diff'] = final_df.groupby(['season', 'round']).qualy_time.diff()
#       8 final_df['qualifying_time'] = final_df.groupby(['season', 'round']).qualy_time_diff.cumsum().fillna(0)
#       9 final_df.drop('qualifying_time_diff', axis = 1, inplace = True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:3925, in GroupBy.diff(self, periods, axis)
#    3922     if len(to_coerce):
#    3923         shifted = shifted.astype({c: "float32" for c in to_coerce})
# -> 3925 return obj - shifted
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/arraylike.py:111, in OpsMixin.__sub__(self, other)
#     109 @unpack_zerodim_and_defer("__sub__")
#     110 def __sub__(self, other):
# --> 111     return self._arith_method(other, operator.sub)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:6262, in Series._arith_method(self, other, op)
#    6260 def _arith_method(self, other, op):
#    6261     self, other = ops.align_method_SERIES(self, other)
# -> 6262     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/base.py:1325, in IndexOpsMixin._arith_method(self, other, op)
#    1322 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1324 with np.errstate(all="ignore"):
# -> 1325     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1327 return self._construct_result(result, name=res_name)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:226, in arithmetic_op(left, right, op)
#     222     _bool_arith_check(op, left, right)
#     224     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     225     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 226     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     228 return res_values
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:172, in _na_arithmetic_op(left, right, op, is_cmp)
#     166 except TypeError:
#     167     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     168         # For object dtype, fallback to a masked operation (only operating
#     169         #  on the non-missing values)
#     170         # Don't do this for comparisons, as that will handle complex numbers
#     171         #  incorrectly, see GH#32047
# --> 172         result = _masked_arith_op(left, right, op)
#     173     else:
#     174         raise
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:110, in _masked_arith_op(x, y, op)
#     108     # See GH#5284, GH#5035, GH#19448 for historical reference
#     109     if mask.any():
# --> 110         result[mask] = op(xrav[mask], yrav[mask])
#     112 else:
#     113     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
final_df.head()
# Out:
#    season  round     circuit_id  warm   cold    dry    wet  cloudy  \
# 0    2020      1  red_bull_ring  True  False  False  False   False
# 1    2020      1  red_bull_ring  True  False  False  False   False
# 2    2020      1  red_bull_ring  True  False  False  False   False
# 3    2020      1  red_bull_ring  True  False  False  False   False
# 4    2020      1  red_bull_ring  True  False  False  False   False
#
#   nationality constructor_x  ...  driver_points  driver_wins  \
# 0     Finnish      mercedes  ...           25.0            1
# 1  Monegasque       ferrari  ...           18.0            0
# 2     British       mclaren  ...           16.0            0
# 3     British      mercedes  ...           12.0            0
# 4     Spanish       mclaren  ...           10.0            0
#
#    driver_standings_pos  constructor_points  constructor_wins  \
# 0                     1                37.0                 1
# 1                     2                19.0                 0
# 2                     3                26.0                 0
# 3                     4                37.0                 1
# 4                     5                26.0                 0
#
#    constructor_standings_pos               driver_y    constructor_y  \
# 0                          1  Valtteri  Bottas  BOT         Mercedes
# 1                          3  Charles  Leclerc  LEC          Ferrari
# 2                          2     Lando  Norris  NOR  McLaren Renault
# 3                          1   Lewis  Hamilton  HAM         Mercedes
# 4                          2     Carlos  Sainz  SAI  McLaren Renault
#
#   qualy_time driver_age
# 0   1:02.939         30
# 1   1:03.923         22
# 2   1:03.626         20
# 3   1:02.951         35
# 4   1:03.971         25
#
# [5 rows x 22 columns]
