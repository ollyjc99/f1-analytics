# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

from sys import platform

if platform == "win32":
    path = 'C:/Users/olive/GitHub/f1-analytics/'
elif platform == "darwin":
    # path = '~/Documents/GitHub/f1-analytics/'
    path = '/Users/oliverjcarter/Documents/GitHub/f1-analytics/'

# %%
years = list(range(2014,  2022 + 1))

# %%
def format_qualifying(x):
    if not any(i in x for i in ['DNF', 'DNS']):
        if ':' in x:
            return round(float(str(x).split(':')[1]) + (60 * float(str(x).split(':')[0])), 3) if x != 0 else 0
        else:
            return(round(float(x), 3))
    else:
        return x

# %%
### Final data collection method to scrape final qualifying results

starting_grid = pd.DataFrame()
for year in years:
    url = 'https://www.formula1.com/en/results.html/{}/races.html'
    r = requests.get(url.format(year))
    soup = BeautifulSoup(r.text, 'html.parser')

    year_links = []
    for page in soup.find_all('a', attrs = {'class':"resultsarchive-filter-item-link FilterTrigger"}):
        link = page.get('href')
        if f'/en/results.html/{year}/races/' in link: 
            year_links.append(link)

    year_df = pd.DataFrame()
    new_url = 'https://www.formula1.com{}'
    for n, link in list(enumerate(year_links)):
        link = link.replace('race-result.html', 'starting-grid.html')
        df = pd.read_html(new_url.format(link))
        df = df[0]
        df['season'] = year
        df['round'] = n + 1
        for col in df:
            if 'Unnamed' in col:
                df.drop(col, axis = 1, inplace = True)

        year_df = pd.concat([year_df, df])

    starting_grid = pd.concat([starting_grid, year_df])

# %%
starting_grid.rename(columns = {'Pos': 'grid', 'Driver': 'driver', 'Car': 'constructor', 'Time': 'final_time', 'No': 'no'}, inplace=True)

starting_grid.drop(['final_time'], axis=1, inplace=True)

starting_grid.shape
# Out:
# (3665, 6)

# %%
starting_grid.query('season == 2021 & round == 10')
# Out:
#     grid  no                    driver                constructor  season  \
# 0      1  33      Max  Verstappen  VER      Red Bull Racing Honda    2021
# 1      2  44      Lewis  Hamilton  HAM                   Mercedes    2021
# 2      3  77     Valtteri  Bottas  BOT                   Mercedes    2021
# 3      4  16     Charles  Leclerc  LEC                    Ferrari    2021
# 4      5   4        Lando  Norris  NOR           McLaren Mercedes    2021
# 5      6   3    Daniel  Ricciardo  RIC           McLaren Mercedes    2021
# 6      7  14     Fernando  Alonso  ALO             Alpine Renault    2021
# 7      8   5    Sebastian  Vettel  VET      Aston Martin Mercedes    2021
# 8      9  31        Esteban  Ocon  OCO             Alpine Renault    2021
# 9     10  55        Carlos  Sainz  SAI                    Ferrari    2021
# 10    11  10        Pierre  Gasly  GAS           AlphaTauri Honda    2021
# 11    12  63      George  Russell  RUS          Williams Mercedes    2021
# 12    13   7      Kimi  Räikkönen  RAI  Alfa Romeo Racing Ferrari    2021
# 13    14  18        Lance  Stroll  STR      Aston Martin Mercedes    2021
# 14    15  99  Antonio  Giovinazzi  GIO  Alfa Romeo Racing Ferrari    2021
# 15    16  22        Yuki  Tsunoda  TSU           AlphaTauri Honda    2021
# 16    17   6     Nicholas  Latifi  LAT          Williams Mercedes    2021
# 17    18  47     Mick  Schumacher  MSC               Haas Ferrari    2021
# 18    19   9      Nikita  Mazepin  MAZ               Haas Ferrari    2021
# 19    20  11        Sergio  Perez  PER      Red Bull Racing Honda    2021
#
#     round
# 0      10
# 1      10
# 2      10
# 3      10
# 4      10
# 5      10
# 6      10
# 7      10
# 8      10
# 9      10
# 10     10
# 11     10
# 12     10
# 13     10
# 14     10
# 15     10
# 16     10
# 17     10
# 18     10
# 19     10

# %%
starting_grid.query('season == 2022')
# Out:
#     grid  no                 driver           constructor  season  round
# 0      1  16  Charles  Leclerc  LEC               Ferrari    2022      1
# 1      2   1   Max  Verstappen  VER  Red Bull Racing RBPT    2022      1
# 2      3  55     Carlos  Sainz  SAI               Ferrari    2022      1
# 3      4  11     Sergio  Perez  PER  Red Bull Racing RBPT    2022      1
# 4      5  44   Lewis  Hamilton  HAM              Mercedes    2022      1
# ..   ...  ..                    ...                   ...     ...    ...
# 15    16  20  Kevin  Magnussen  MAG          Haas Ferrari    2022     22
# 16    17  10     Pierre  Gasly  GAS       AlphaTauri RBPT    2022     22
# 17    18  77  Valtteri  Bottas  BOT    Alfa Romeo Ferrari    2022     22
# 18    19  23  Alexander  Albon  ALB     Williams Mercedes    2022     22
# 19    20   6  Nicholas  Latifi  LAT     Williams Mercedes    2022     22
#
# [436 rows x 6 columns]

# %%
starting_grid.to_csv(path+'data/starting-grid.csv', index=False)
