# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

from sys import platform

if platform == "win32":
    path = 'C:/Users/olive/GitHub/f1-analytics/'
elif platform == "darwin":
    # path = '~/Documents/GitHub/f1-analytics/'
    path = '/Users/oliverjcarter/Documents/GitHub/f1-analytics/'

# %%
years = list(range(2014,  2022))

# %%
def format_qualifying(x):
    if not any(i in x for i in ['DNF', 'DNS']):
        if ':' in x:
            return round(float(str(x).split(':')[1]) + (60 * float(str(x).split(':')[0])), 3) if x != 0 else 0
        else:
            return(round(float(x), 3))
    else:
        return x

# %%
### Final data collection method to scrape final qualifying results

starting_grid = pd.DataFrame()
for year in years:
    url = 'https://www.formula1.com/en/results.html/{}/races.html'
    r = requests.get(url.format(year))
    soup = BeautifulSoup(r.text, 'html.parser')

    year_links = []
    for page in soup.find_all('a', attrs = {'class':"resultsarchive-filter-item-link FilterTrigger"}):
        link = page.get('href')
        if f'/en/results.html/{year}/races/' in link: 
            year_links.append(link)

    year_df = pd.DataFrame()
    new_url = 'https://www.formula1.com{}'
    for n, link in list(enumerate(year_links)):
        link = link.replace('race-result.html', 'starting-grid.html')
        df = pd.read_html(new_url.format(link))
        df = df[0]
        df['season'] = year
        df['round'] = n+1
        for col in df:
            if 'Unnamed' in col:
                df.drop(col, axis = 1, inplace = True)

        year_df = pd.concat([year_df, df])

    starting_grid = pd.concat([starting_grid, year_df])

# %%
starting_grid.rename(columns = {'Pos': 'grid', 'Driver': 'driver', 'Car': 'constructor', 'Time': 'final_time'}, inplace=True)

starting_grid.drop(['No'], axis=1, inplace=True)

starting_grid.shape
# Out:
# (3229, 6)

# %%
starting_grid.query('season == 2021 & round == 10')
# Out:
#     grid                    driver                constructor final_time  \
# 0      1      Max  Verstappen  VER      Red Bull Racing Honda        NaN
# 1      2      Lewis  Hamilton  HAM                   Mercedes        NaN
# 2      3     Valtteri  Bottas  BOT                   Mercedes        NaN
# 3      4     Charles  Leclerc  LEC                    Ferrari        NaN
# 4      5        Lando  Norris  NOR           McLaren Mercedes        NaN
# 5      6    Daniel  Ricciardo  RIC           McLaren Mercedes        NaN
# 6      7     Fernando  Alonso  ALO             Alpine Renault        NaN
# 7      8    Sebastian  Vettel  VET      Aston Martin Mercedes        NaN
# 8      9        Esteban  Ocon  OCO             Alpine Renault        NaN
# 9     10        Carlos  Sainz  SAI                    Ferrari        NaN
# 10    11        Pierre  Gasly  GAS           AlphaTauri Honda        NaN
# 11    12      George  Russell  RUS          Williams Mercedes        NaN
# ...

# %%
starting_grid['final_time'] = starting_grid.final_time.map(lambda x: format_qualifying(str(x)))

starting_grid['final_time'].describe()
# Out:
# count    3058.000000
# mean       88.158361
# std        13.864620
# min        53.377000
# 25%        76.969500
# 50%        88.046500
# 75%        97.210250
# max       141.611000
# Name: final_time, dtype: float64

# %%
# calculate difference in qualifying times

starting_grid = starting_grid[starting_grid['final_time'] != 0]
starting_grid.sort_values(['season', 'round', 'grid'], inplace = True)
starting_grid['time_difference'] = starting_grid.groupby(['season', 'round']).final_time.diff()
starting_grid['q_delta'] = starting_grid.groupby(['season', 'round']).time_difference.cumsum().fillna(0)
starting_grid.drop('time_difference', axis=1, inplace=True)

starting_grid.head()
# Out:
#    grid                  driver              constructor  final_time  season  \
# 0     1    Lewis  Hamilton  HAM                 Mercedes     104.231    2014
# 1     2  Daniel  Ricciardo  RIC  Red Bull Racing Renault     104.548    2014
# 2     3      Nico  Rosberg  ROS                 Mercedes     104.595    2014
# 3     4   Kevin  Magnussen  MAG         McLaren Mercedes     105.745    2014
# 4     5   Fernando  Alonso  ALO                  Ferrari     105.819    2014
#
#    round  q_delta
# 0      1    0.000
# 1      1    0.317
# 2      1    0.364
# 3      1    1.514
# 4      1    1.588

# %%
starting_grid.query('grid == 0')
# Out:
# Empty DataFrame
# Columns: [grid, driver, constructor, final_time, season, round, q_delta]
# Index: []

# %%
# qualy_df.to_csv(path+'data/qualifying.csv', index=False)
